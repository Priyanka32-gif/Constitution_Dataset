# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Constitution Dataset.csv')

# %%
df.head()
# Out:
#        Country  Year Enacted  Scope Length (in Words)  Executive Power  \
# 0  Afghanistan          2004   0.67            10,227                6
# 1      Albania          1998   0.61            13,826                5
# 2      Algeria          1996   0.61            10,038                7
# 3      Andorra          1993   0.51             8,740                6
# 4       Angola          2010   0.80            27,181                7
#
#    Legislative Power  Judicial Independence  Number of Rights  \
# 0               0.38                      2                37
# 1               0.43                      5                77
# 2               0.29                      1                36
# 3               0.19                      3                51
# 4               0.19                      2                80
#
#                                             Preamble
# 0  In the name of Allah, the Most Beneficent, the...
# 1  We, the people of Albania, proud and aware of ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                190 non-null    object
#  1   Year Enacted           190 non-null    int64
#  2   Scope                  190 non-null    float64
#  3   Length (in Words)      190 non-null    object
#  4   Executive Power        190 non-null    int64
#  5   Legislative Power      190 non-null    float64
#  6   Judicial Independence  190 non-null    int64
#  7   Number of Rights       190 non-null    int64
#  8   Preamble               159 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        Year Enacted       Scope  Executive Power  Legislative Power  \
# count    190.000000  190.000000       190.000000         190.000000
# mean    1975.873684    0.583158         4.357895           0.293263
# std       66.244415    0.105181         1.726947           0.114536
# min     1215.000000    0.210000         0.000000           0.000000
# 25%     1975.000000    0.510000         3.000000           0.190000
# 50%     1991.000000    0.600000         4.000000           0.330000
# 75%     1998.750000    0.660000         6.000000           0.380000
# max     2014.000000    0.810000         7.000000           0.620000
#
#        Judicial Independence  Number of Rights
# count             190.000000        190.000000
# mean                2.594737         50.036842
# std                 1.472490         18.035934
# min                 0.000000          2.000000
# 25%                 1.000000         37.250000
# 50%                 2.000000         49.000000
# ...

# %%
df['text_length'] = df['Preamble'].str.len()

# %%
df['text_length']
# Out:
# 0      1733.0
# 1       731.0
# 2      8593.0
# 3      1611.0
# 4      3701.0
#         ...
# 185     439.0
# 186    1404.0
# 187    2997.0
# 188    1287.0
# 189    1397.0
# Name: text_length, Length: 190, dtype: float64

# %%
#df['Year Enacted'].unique()
#df['Executive Power'].unique()
#df['Judicial Independence'].unique()
#df['Country'].unique()

# %%
sns.set_style('white')

# %%
graph = sns.FacetGrid(df,col='Executive Power')
graph.map(sns.histplot,'text_length')

# %%
graph = sns.FacetGrid(df,col='Judicial Independence')
graph.map(sns.histplot,'text_length')

# %%
sns.boxplot(df,y='text_length',x='Executive Power')
# Out:
# <AxesSubplot: xlabel='Executive Power', ylabel='text_length'>

# %%
sns.boxplot(df,y='text_length',x='Judicial Independence')
# Out:
# <AxesSubplot: xlabel='Judicial Independence', ylabel='text_length'>

# %%
sns.countplot(df,x='Executive Power')
# Out:
# <AxesSubplot: xlabel='Executive Power', ylabel='count'>

# %%
sns.countplot(df,x='Judicial Independence')
# Out:
# <AxesSubplot: xlabel='Judicial Independence', ylabel='count'>

# %%
Executive = df.groupby('Executive Power').mean()
Executive
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21928\2848033638.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Executive = df.groupby('Executive Power').mean()
#                  Year Enacted     Scope  Legislative Power  \
# Executive Power
# 0                 1586.500000  0.410000           0.140000
# 1                 1939.571429  0.470000           0.264286
# 2                 1971.294118  0.523529           0.271765
# 3                 1983.142857  0.569048           0.281429
# 4                 1970.034483  0.574483           0.289310
# 5                 1974.263158  0.615789           0.322105
# 6                 1995.733333  0.626000           0.338000
# 7                 1993.480000  0.602000           0.255200
#
# ...

# %%
Judicial = df.groupby('Judicial Independence').mean()
Judicial
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21928\3260411959.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Judicial = df.groupby('Judicial Independence').mean()
#                        Year Enacted     Scope  Executive Power  \
# Judicial Independence
# 0                       1984.875000  0.520000         3.750000
# 1                       1976.187500  0.561042         4.750000
# 2                       1980.850000  0.578000         4.850000
# 3                       1948.941176  0.576176         4.294118
# 4                       1981.780488  0.600488         3.878049
# 5                       1996.866667  0.640667         3.733333
# 6                       1994.000000  0.692500         3.750000
#
#                        Legislative Power  Number of Rights  text_length
# ...

# %%
executive_corr = Executive.corr()
executive_corr
# Out:
#                        Year Enacted     Scope  Legislative Power  \
# Year Enacted               1.000000  0.805420           0.895231
# Scope                      0.805420  1.000000           0.853073
# Legislative Power          0.895231  0.853073           1.000000
# Judicial Independence     -0.568404 -0.686239          -0.350416
# Number of Rights           0.911428  0.854811           0.972053
# text_length                0.254926 -0.257539           0.055429
#
#                        Judicial Independence  Number of Rights  text_length
# Year Enacted                       -0.568404          0.911428     0.254926
# Scope                              -0.686239          0.854811    -0.257539
# Legislative Power                  -0.350416          0.972053     0.055429
# Judicial Independence               1.000000         -0.428952     0.098714
# Number of Rights                   -0.428952          1.000000     0.068261
# ...

# %%
sns.heatmap(executive_corr, annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot: >

# %%
judicial_corr = Judicial.corr()
judicial_corr
# Out:
#                    Year Enacted     Scope  Executive Power  Legislative Power  \
# Year Enacted           1.000000  0.465747        -0.458851           0.499514
# Scope                  0.465747  1.000000        -0.389685           0.934659
# Executive Power       -0.458851 -0.389685         1.000000          -0.167047
# Legislative Power      0.499514  0.934659        -0.167047           1.000000
# Number of Rights       0.428529  0.893465        -0.326463           0.809934
# text_length           -0.190792 -0.637119         0.606999          -0.329667
#
#                    Number of Rights  text_length
# Year Enacted               0.428529    -0.190792
# Scope                      0.893465    -0.637119
# Executive Power           -0.326463     0.606999
# Legislative Power          0.809934    -0.329667
# Number of Rights           1.000000    -0.616310
# text_length               -0.616310     1.000000

# %%
sns.heatmap(judicial_corr,cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot: >

# %%
 Highest_right = df[['Number of Rights','Country']]

# %%
top_values = Highest_right.sort_values(by='Number of Rights',ascending=False).head(15)

# %%
top_values.plot(kind='bar', x= 'Country', y='Number of Rights',figsize = (12,10))
plt.title('Top 15 Countries with highest number of Rights')
# Out:
# Text(0.5, 1.0, 'Top 15 Countries with highest number of Rights')

# %%
bottom_values = Highest_right.sort_values(by='Number of Rights',ascending=False).tail(15)

# %%
bottom_values
# Out:
#      Number of Rights       Country
# 47                 26      Djibouti
# 121                26   Netherlands
# 112                26        Monaco
# 37                 23       Comoros
# 46                 21       Denmark
# 172                20         Tonga
# 150                18     Singapore
# 145                15  Saudi Arabia
# 9                  15       Austria
# 93                 14       Lebanon
# 59                 13        France
# 8                  11     Australia
# 80                  6        Israel
# 24                  2        Brunei
# 169                 2      Thailand

# %%
bottom_values.plot(kind='bar', x= 'Country', y='Number of Rights',figsize = (12,10))
plt.title('Top 15 Countries with lowest number of Rights')
# Out:
# Text(0.5, 1.0, 'Top 15 Countries with lowest number of Rights')

# %%
plt.figure(figsize = (16, 5))
ax = sns.countplot(data= df, x = 'Year Enacted')
labels = df.groupby(df['Year Enacted']).count()['Country'].values
plt.title('No of Constitutions per year')
plt.xticks(rotation = 45, ha = 'right') 
plt.show()

# %%
from wordcloud import WordCloud

# %%
df['Preamble'].isnull().sum()
# Out:
# 31

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# Country                  0
# Year Enacted             0
# Scope                    0
# Length (in Words)        0
# Executive Power          0
# Legislative Power        0
# Judicial Independence    0
# Number of Rights         0
# Preamble                 0
# text_length              0
# dtype: int64

# %%
df_class = df[(df['Executive Power']== 1) |(df['Executive Power']==7)]

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 2 to 178
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                29 non-null     object
#  1   Year Enacted           29 non-null     int64
#  2   Scope                  29 non-null     float64
#  3   Length (in Words)      29 non-null     object
#  4   Executive Power        29 non-null     int64
#  5   Legislative Power      29 non-null     float64
#  6   Judicial Independence  29 non-null     int64
#  7   Number of Rights       29 non-null     int64
#  8   Preamble               29 non-null     object
#  9   text_length            29 non-null     float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 2.5+ KB

# %%
X = df_class['Preamble']
y = df_class['Executive Power']

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
X = cv.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
nb = MultinomialNB()

# %%
nb.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
prediction = nb.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,prediction))
print('\n')
print(confusion_matrix(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         1
#            7       0.90      1.00      0.95         9
#
#     accuracy                           0.90        10
#    macro avg       0.45      0.50      0.47        10
# weighted avg       0.81      0.90      0.85        10
#
#
#
# [[0 1]
#  [0 9]]
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([('count',CountVectorizer()),
               ('tfidf',TfidfTransformer()),
               ('model',MultinomialNB())])

# %%
df_class = df[(df['Judicial Independence']==0)|(df['Judicial Independence']==6)]   
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 5 to 187
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                12 non-null     object
#  1   Year Enacted           12 non-null     int64
#  2   Scope                  12 non-null     float64
#  3   Length (in Words)      12 non-null     object
#  4   Executive Power        12 non-null     int64
#  5   Legislative Power      12 non-null     float64
#  6   Judicial Independence  12 non-null     int64
#  7   Number of Rights       12 non-null     int64
#  8   Preamble               12 non-null     object
#  9   text_length            12 non-null     float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 1.0+ KB

# %%
X = df_class['Preamble']
y = df_class['Judicial Independence']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('count', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('model', MultinomialNB())])

# %%
prediction = pipe.predict(X_test)

# %%
print(classification_report(y_test,prediction))
print('\n')
print(confusion_matrix(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86         3
#            6       0.00      0.00      0.00         1
#
#     accuracy                           0.75         4
#    macro avg       0.38      0.50      0.43         4
# weighted avg       0.56      0.75      0.64         4
#
#
#
# [[3 0]
#  [1 0]]
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
